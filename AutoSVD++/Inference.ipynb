# %% [markdown]
# # Part 1 AutoSVD

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/AutoSVD++
# Out:
# /content/drive/MyDrive/AutoSVD++

# %%
# !pip install result

# %%
# !python predict_AutoSVD.py
# Out:
# Number of users=86; Number of items=100
#
#  ============== predict ratings of user  76  ==============
#
#                    user_id    name  ...  compliment_writer compliment_photos
# 45  qjfMBIZpQT9DDtw_BWCopQ  Rachel  ...                447              1850
#
# [1 rows x 22 columns]
#
#  ========= predict user's rating of each business =========
#
# business_idx = 0  predicted_star = 4.494728321035647
# business_idx = 1  predicted_star = 3.0931302087494745
# business_idx = 2  predicted_star = 4.446985706410885
# business_idx = 3  predicted_star = 3.8312786554171416
# business_idx = 4  predicted_star = 4.133432213432119
# business_idx = 5  predicted_star = 4.614943776535536
# business_idx = 6  predicted_star = 3.408077831926062
# business_idx = 7  predicted_star = 4.200763487994032
# business_idx = 8  predicted_star = 4.208073306079113
# business_idx = 9  predicted_star = 3.9914234203643515
# business_idx = 10  predicted_star = 4.182152655846358
# ...

# %%
from models.AutoSVD import AutoSVD
from utils.YelpRecommendationGenerator import *

autosvd = AutoSVD(path_of_feature_file="datasets/subsets/restaurant_features_encoded.csv")
autosvd.load_model()
yelp_recommender = YelpRecommendationGenerator(autosvd)
sorted_df, recommendations_df = yelp_recommender.load_recommendations_autosvd()

# %%
sorted_df
# Out:
#        stars  business_idx             business_id
# 0   4.954856            72  ctHjyadbDQAtUFfkcAFEHw
# 1   4.814861            43  LmKpHMXSsm36viJOGVodFw
# 2   4.663837            49  R17gwW6zn9ilslbdvKdgsg
# 3   4.656176            73  dsfRniRgfbDjC8os848B6A
# 4   4.614944             5  2KIDQyTh-HzLxOUEDqtDBg
# ..       ...           ...                     ...
# 95  3.612186            13  8O35ji_yOMVJmZ6bl96yhQ
# 96  3.445184            75  ezB8e2rijjViprrcTdIiQQ
# 97  3.408078             6  3YqUe2FTCQr0pPVK8oCv6Q
# 98  3.093130             1  -QI8Qi8XWH3D8y8ethnajA
# 99  2.896114            23  Eb1XmmLWyt_way5NNZ7-Pw
#
# [100 rows x 3 columns]

# %%
recommendations_df
# Out:
#               business_id                         name  \
# 0  ctHjyadbDQAtUFfkcAFEHw                        Zahav
# 1  LmKpHMXSsm36viJOGVodFw    Missouri Botanical Garden
# 2  R17gwW6zn9ilslbdvKdgsg                 Alma de Cuba
# 3  dsfRniRgfbDjC8os848B6A           Bern's Steak House
# 4  2KIDQyTh-HzLxOUEDqtDBg     Mazzaro's Italian Market
# 5  cQIh4YJlVtZI9TLF5_smOg              The Shaved Duck
# 6  ytynqOUb3hjKeJfRj5Tshw      Reading Terminal Market
# 7  gGyqnAlpFrka_qzpO7j4lQ           Citizens Bank Park
# 8  P-TC0VSnUsct3NhYrj5xOA      Thinh An Kitchen & Tofu
# 9  _0QZGrg91aaiMhh7tQyYYg  Jacksons Bistro Bar & Sushi
#
#                               address              city state  postal_code  \
# 0                     237 St James Pl      Philadelphia    PA        19106
# 1                      4344 Shaw Blvd       Saint Louis    MO        63110
# 2                      1623 Walnut St      Philadelphia    PA        19103
# ...

# %% [markdown]
# # Part 2 AutoSVD++

# %%
# !python predict_AutoSVDpp.py
# Out:
# Number of users=86; Number of items=100
#
#  ============== predict ratings of user  76  ==============
#
#                    user_id    name  ...  compliment_writer compliment_photos
# 45  qjfMBIZpQT9DDtw_BWCopQ  Rachel  ...                447              1850
#
# [1 rows x 22 columns]
#
#  ========= predict user's rating of each business =========
#
# business_idx = 0  predicted_star = 4.453458152750127
# business_idx = 1  predicted_star = 3.218876293857673
# business_idx = 2  predicted_star = 4.407611389028872
# business_idx = 3  predicted_star = 4.01326466857394
# business_idx = 4  predicted_star = 4.271522415913888
# business_idx = 5  predicted_star = 4.640213352675768
# business_idx = 6  predicted_star = 3.6890099475557783
# business_idx = 7  predicted_star = 4.248532555071607
# business_idx = 8  predicted_star = 4.375365431606073
# business_idx = 9  predicted_star = 4.19881277280289
# business_idx = 10  predicted_star = 4.070508086617829
# ...

# %%
from models.AutoSVDpp import AutoSVDpp
from utils.YelpRecommendationGenerator import *

autosvdpp = AutoSVDpp(path_of_feature_file="datasets/subsets/restaurant_features_encoded.csv")
autosvdpp.load_model()
yelp_recommender = YelpRecommendationGenerator(autosvd)
sorted_df, recommendations_df = yelp_recommender.load_recommendations_autosvdpp()

# %%
sorted_df
# Out:
#        stars  business_idx             business_id
# 0   4.974286            72  ctHjyadbDQAtUFfkcAFEHw
# 1   4.770669            43  LmKpHMXSsm36viJOGVodFw
# 2   4.700330            73  dsfRniRgfbDjC8os848B6A
# 3   4.672156            96  ytynqOUb3hjKeJfRj5Tshw
# 4   4.650525            27  Fx_yFwHlHboVTTj-4NJQyg
# ..       ...           ...                     ...
# 95  3.592556            68  bZ2mNCf64JlX-_U5eDOcQg
# 96  3.580140            13  8O35ji_yOMVJmZ6bl96yhQ
# 97  3.462821            75  ezB8e2rijjViprrcTdIiQQ
# 98  3.218876             1  -QI8Qi8XWH3D8y8ethnajA
# 99  2.988760            23  Eb1XmmLWyt_way5NNZ7-Pw
#
# [100 rows x 3 columns]

# %%
recommendations_df
# Out:
#               business_id                         name  \
# 0  ctHjyadbDQAtUFfkcAFEHw                        Zahav
# 1  LmKpHMXSsm36viJOGVodFw    Missouri Botanical Garden
# 2  dsfRniRgfbDjC8os848B6A           Bern's Steak House
# 3  ytynqOUb3hjKeJfRj5Tshw      Reading Terminal Market
# 4  Fx_yFwHlHboVTTj-4NJQyg       Milagro Modern Mexican
# 5  2KIDQyTh-HzLxOUEDqtDBg     Mazzaro's Italian Market
# 6  qISf5ojuYbD9h71NumGUQA                  Han Dynasty
# 7  _C7QiQQc47AOEv4PE3Kong           Commander's Palace
# 8  gGyqnAlpFrka_qzpO7j4lQ           Citizens Bank Park
# 9  _0QZGrg91aaiMhh7tQyYYg  Jacksons Bistro Bar & Sushi
#
#                               address              city state  postal_code  \
# 0                     237 St James Pl      Philadelphia    PA        19106
# 1                      4344 Shaw Blvd       Saint Louis    MO        63110
# 2                   1208 S Howard Ave             Tampa    FL        33606
# ...
